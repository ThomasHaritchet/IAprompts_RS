# %%
import random
import os

# %%
prompts = [
    "🎈 ¡Hacé de tu fiesta un éxito con nuestros inflables! 🏰 Diversión asegurada para los más chicos. Reservá el tuyo ahora. 📅🎉",
    "⚽ ¡Metegoles disponibles para tu evento! Desafiá a tus amigos y pasá un momento increíble. 🤩 Reservá ya.",
    "🎊 ¡Sumá diversión a tu fiesta con nuestros inflables! Reservá ahora y garantizá un día inolvidable. 💥🎉",
]

# %%
prompt_seleccionado = random.choice(prompts)
print(f"📢 Prompt seleccionado: {prompt_seleccionado}")
# Out:
# 📢 Prompt seleccionado: 🎊 ¡Sumá diversión a tu fiesta con nuestros inflables! Reservá ahora y garantizá un día inolvidable. 💥🎉

# %%
imagen_generada = "imagen_generada.jpg"

# %%
if os.path.exists(imagen_generada):
    from PIL import Image
    from IPython.display import display

    img = Image.open(imagen_generada)
    display(img)
else:
    print(f"⚠️ No se encontró la imagen. Generala en NightCafe y guardala como '{imagen_generada}'.")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
opcion_1 = "🎈 ¡Hacé de tu fiesta un éxito con nuestros inflables! 🏰 Diversión asegurada para los más chicos. Reservá el tuyo ahora. 📅🎉"
opcion_2 = "🎉 ¡Fiesta asegurada! 🏰 Traemos la diversión con nuestros inflables. 📅 Reservá hoy."

# %%
print("📊 Comparación de prompts:")
print(f"- Opción 1: {opcion_1}")
print(f"- Opción 2: {opcion_2}")

print("\n✅ Conclusión: La opción 2 es más llamativa, con emojis y un llamado a la acción más claro.")
# Out:
# 📊 Comparación de prompts:
# - Opción 1: 🎈 ¡Hacé de tu fiesta un éxito con nuestros inflables! 🏰 Diversión asegurada para los más chicos. Reservá el tuyo ahora. 📅🎉
# - Opción 2: 🎉 ¡Fiesta asegurada! 🏰 Traemos la diversión con nuestros inflables. 📅 Reservá hoy.
#
# ✅ Conclusión: La opción 2 es más llamativa, con emojis y un llamado a la acción más claro.

# %%
cd "C:\Users\Thoma\Downloads\Data sciense\IA"
# Out:
# C:\Users\Thoma\Downloads\Data sciense\IA
